# %% [markdown]
# # Task 2 – Python Programming
# ### Conditional Statements, Loops, and Functions

# %% [markdown]
# ## 1. Conditional Statements

# %% [markdown]
#  i. Write a program to Check wheather a year is a leap year or not

# %%
year = int(input("Enter a year: "))

if (year % 4 == 0 ):
    print("It is a Leap year")
else:
    print("It is not a Leap year")
# Out:
# Enter a year: 1999
# It is not a Leap year

# %% [markdown]
# ii. Write a program to check whether the person is a Senior Citizen or not

# %%
age = int(input("Enter your age: "))

if age >= 60:
    print("The person is a senior citizen")
else:
    print("The person is not a senior citizen")
# Out:
# Enter your age: 77
# The person is a senior citizen

# %% [markdown]
# iii. Get 3 ages input from the user and check who is the oldest person

# %%
a1 = int(input("Enter first age: "))
a2 = int(input("Enter second age: "))
a3 = int(input("Enter third age: "))

if a1 >= a2 and a1 >= a3:
    print("The first person is the oldest")
elif a2 >= a1 and a2 >= a3:
    print("The second person is the oldest")
else:
    print("The third person is the oldest")
# Out:
# Enter first age: 38
# Enter second age: 37
# Enter third age: 25
# First person is the oldest

# %% [markdown]
# iv. Check the experiance of the user and gives a diwali bonus according to their experience.

# %%
exp = int(input("Enter your years of experience: "))

if exp >= 10:
    bonus = 10000
elif exp >= 5:
    bonus = 5000
elif exp >= 2:
    bonus = 2500
else:
    bonus = 1000

print("Diwali bonus:", bonus)
# Out:
# Enter your years of experience: 6
# Diwali bonus: 5000

# %% [markdown]
# v. Check whether the person wants to take a book from the library.
#
# 。 If they want to take a book, check if they have a library card or not.
#
# 。 If they have a library card, get input from the user for which book they need to take and remove that book from the list of books in the library.

# %%
books = ["Python", "Java", "C", "Javascript", "SQL", "Basic fundamentals of Computer"]

want_book = input("Do you want to take a book? (yes/no): ")

if want_book == "yes":
    card = input("Do you have a library card? (yes/no): ")

    if card == "yes":
        print("Available books:", books)
        book = input("Which book do you need? ")

        if book in books:
            books.remove(book)
            print("Book issued successfully.")
            print("Remaining avaolable books:", books)
        else:
            print("Book is not available.")
    else:
        print("You need a library card.")
# Out:
# Do you want to take a book? (yes/no): no

# %% [markdown]
# ## 2. Loops

# %% [markdown]
# i. Write a program to print the factorial of a number.

# %%
n = int(input("Enter a number: "))
factorial = 1

for i in range(1, n + 1):
    factorial *= i

print("Factorial:", factorial)
# Out:
# Enter a number: 5
# Factorial: 120

# %% [markdown]
# ii. Write a program to check whether the number is Armstrong or not.

# %%
num = int(input("Enter a number: "))
original = num
digits = len(str(num))
total = 0

while num > 0:
    digit = num % 10
    total += digit ** digits
    num //= 10

if total == original:
    print("It is an armstrong number")
else:
    print("It is not an armstrong number")
# Out:
# Enter a number: 153
# It is an armstrong number

# %% [markdown]
# iii. Write a program to print a star pattern.

# %%
n = int(input("Enter number of rows: "))

for i in range(1, n + 1):
    print("* " * i)
# Out:
# Enter number of rows: 10
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *
# * * * * * * *
# * * * * * * * *
# * * * * * * * * *
# * * * * * * * * * *

# %% [markdown]
# iv. Write a program to print the sum of digits accepted from the user.

# %%
n = int(input("Enter a number: "))
total = 0

while n > 0:
    digit = n % 10
    total += digit
    n //= 10

print("Sum of digits:", total)
# Out:
# Enter a number: 17
# Sum of digits: 8

# %% [markdown]
# v. Accept 10 numbers from the user and display the average of all the numbers.

# %%
total = 0

for i in range(10):
    num = int(input(f"Enter number {i + 1} : "))
    total += num

average = total / 10
print("Average:", average)
# Out:
# Enter number 1 : 3
# Enter number 2 : 5
# Enter number 3 : 3
# Enter number 4 : 4
# Enter number 5 : 6
# Enter number 6 : 7
# Enter number 7 : 8
# Enter number 8 : 9
# Enter number 9 : 1
# Enter number 10 : 2
# Average: 4.8

# %% [markdown]
# vi. Write a program to print the multiplication tables from 1 to 10 using nested loops.

# %%
for i in range(1, 11):
    print(f"\nMultiplication Table of {i}")
    for j in range(1, 11):
        print(f"{i} x {j} = {i * j}")
# Out:
# Multiplication Table of 1
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10
#
# Multiplication Table of 2
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
#
# Multiplication Table of 3
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
#
# Multiplication Table of 4
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
#
# Multiplication Table of 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
#
# Multiplication Table of 6
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
#
# Multiplication Table of 7
# 7 x 1 = 7
# 7 x 2 = 14
# ...

# %% [markdown]
# ## 3. Functions

# %% [markdown]
# i. Write a Python function that takes a list and returns a new list with distinct (unique) elements from the first list.

# %%
def unique_elements(my_list):
    return list(dict.fromkeys(my_list))

sample_list = [1, 2, 3, 3, 3, 3, 4, 5]
print("Original list:", sample_list)
print("Unique list:", unique_elements(sample_list))
# Out:
# Original list: [1, 2, 3, 3, 3, 3, 4, 5]
# Unique list: [1, 2, 3, 4, 5]

# %% [markdown]
# ii. Write a function count_vowels(string) that takes a string and returns the number of vowels (a, e, i, o, u) in the string.

# %%
def count_vowels(string):
    count = 0
    for char in string.lower():
        if char in "aeiou":
            count += 1
    return count

text = input("Enter a string: ")
print("Number of vowels:", count_vowels(text))
# Out:
# Enter a string: Abhibash
# Number of vowels: 3

# %% [markdown]
# iii. Create a function is prime(n) that takes a number and returns True if the number is prime, otherwise False.

# %%
def is_prime(n):
    if n < 2:
        return False

    for i in range(2, n):
        if n % i == 0:
            return False

    return True

number = int(input("Enter a number: "))
print(is_prime(number))
# Out:
# Enter a number: 7
# True

# %% [markdown]
# iv. Create a simple calculator function.

# %%
def calculator(a, b, operator):

    if operator == "+":
        return a + b
    elif operator == "-":
        return a - b
    elif operator == "*":
        return a * b
    elif operator == "/":
        if b == 0:
            return "Cannot divide by zero"
        return a / b
    else:
        return "Invalid operator"

operator = input("Enter the operator (+, -, *, /): ")
num1 = int(input("Enter the first number  : "))
num2 = int(input("Enter the second number : "))


print("Result:", calculator(num1, num2, operator))
# Out:
# Enter the operator (+, -, *, /): +
# Enter the first number  : 20
# Enter the second number : 48
# Result: 68
