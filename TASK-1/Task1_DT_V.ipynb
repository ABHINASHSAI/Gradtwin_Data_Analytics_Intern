# %% [markdown]
#  Task – 1: Variables and Data Types

# %% [markdown]
# ### 1. Write a Python program to create a variable name and print your name.

# %%
name = "Sai"
print(name)
# Out:
# Sai

# %% [markdown]
# ### 2. Write a program to create an age variable and print your age.

# %%
age = 21
print(age)
# Out:
# 21

# %% [markdown]
# ### 3. Write a program to store two numbers in variables and print their sum.

# %%
num1 = 17
num2 = 7
sum = num1 + num2
print(sum)
# Out:
# 24

# %% [markdown]
# ### 4. Write a program to store two numbers and print their difference.

# %%
num1 = 20
num2 = 10
diff = num1 - num2
print(diff)
# Out:
# 10

# %% [markdown]
# ### 5. Write a program to store two numbers and print their product.

# %%
num1 = 17
num2 = 3
prod = num1 * num2
print(prod)
# Out:
# 51

# %% [markdown]
# ### 6. Write a program to store two numbers and print their division result.

# %%
num1 = 20
num2 = 5
div = num1 / num2
print(div)
# Out:
# 4.0

# %% [markdown]
# ### 7. Write a program to calculate the area of a rectangle using variables length and breadth.

# %%
leng = 10
breadth = 5

area = leng * breadth
print(area)
# Out:
# 50

# %% [markdown]
# ### 8. Write a program to calculate the perimeter of a rectangle.

# %%
leng = 7
breadth = 6

perimeter = 2 * (leng + breadth)
print(perimeter)
# Out:
# 26

# %% [markdown]
# ### 9. Write a program to calculate the area of a circle using a variable radius.

# %%
radius = 7

area = 3.14 * radius * radius
print(area)
# Out:
# 153.86

# %% [markdown]
# ### 10. Write a program to convert Celsius temperature into Fahrenheit.

# %%
celsius = 30

fahrenheit = (celsius * 9/5) + 32
print(fahrenheit)
# Out:
# 86.0

# %% [markdown]
# ### 11. Write a program to store a student's marks in 5 subjects and calculate the total.

# %%
sub1 = 70
sub2 = 76
sub3 = 89
sub4 = 84
sub5 = 89

total = sub1 + sub2 + sub3 + sub4 + sub5
print(total)
# Out:
# 408

# %% [markdown]
# ### 12. Write a program to calculate the average of 3 numbers.

# %%
a = 10
b = 20
c = 30

average = (a + b + c) / 3
print(average)
# Out:
# 20.0

# %% [markdown]
# ### 13. Write a program to convert meters into centimeters.

# %%
m = 7

cm = m * 100
print(cm)
# Out:
# 700

# %% [markdown]
# ### 14. Write a program to convert kilometers into meters.

# %%
km = 5

m = km * 1000
print(m)
# Out:
# 5000

# %% [markdown]
# ### 15. Write a program to calculate simple interest using principal, rate, and time.

# %%
principal = 10000
rate = 5
time = 2

si = (principal * rate * time) / 100
print(si)
# Out:
# 1000.0

# %% [markdown]
# ### 16. Write a program to swap the values of two variables.

# %%
a = 10
b = 20

a, b = b, a

print(a)
print(b)
# Out:
# 20
# 10

# %% [markdown]
# ### 17. Write a program to take the user's name as input and print "Hello, <name>".

# %%
name = input("Enter your name: ")

print("Hello,", name)

# %% [markdown]
# ### 18. Write a program to take two numbers as input and print their sum.

# %%
a = int(input("Enter first number : "))
b = int(input("Enter second number: "))

sum = a + b
print(sum)

# %% [markdown]
# ### 19. Write a program to take a person's age as input and print the age after 5 years.

# %%
age = int(input("Enter your age: "))

new_age = age + 5
print(new_age)

# %% [markdown]
# ### 20. Write a program to take the length and breadth of a rectangle from the user and calculate its area.

# %%
length = int(input("Enter length  : "))
breadth = int(input("Enter breadth : "))

area = length * breadth
print("Area of the Rectangle:",area)

# %% [markdown]
# ### 21. Write a program to check and print the data type of a variable.

# %%
a = 10
b = "Ram"
c = 17.3
d = 7 + 3j
e = True


print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))

# %% [markdown]
# ### 22. Write a program to create an integer and convert it into a float.

# %%
num = 10

float_num = float(num)

print(float_num)
print(type(float_num))

# %% [markdown]
# ### 23. Write a program to create a float and convert it into an integer.

# %%
num = 10.5

int_num = int(num)

print(int_num)

print(type(int_num))

# %% [markdown]
# ### 24. Write a program to convert a string "123" into an integer.

# %%
num = "123"

int_num = int(num)

print(int_num)

print(type(int_num))

# %% [markdown]
# ### 25. Write a program to convert an integer into a string.

# %%
num = 123

string_num = str(num)

print(string_num)

print(type(string_num))

# %% [markdown]
# ### 26. Write a program to create variables of type int, float, str, and bool, and print their types.

# %%
a = 10
b = 10.5
c = "Hello"
d = True

print(type(a))
print(type(b))
print(type(c))
print(type(d))

# %% [markdown]
# ### 27. Write a program to take a number as input and print its square.

# %%
num = int(input("Enter a number: "))

square = num * num

print("Square :",square)

# %% [markdown]
# ### 28. Write a program to take a number as input and print its cube.

# %%
num = int(input("Enter a number: "))

cube = num * num * num

print("Cube : ",cube)

# %% [markdown]
# ### 29. Write a program to calculate the total price of 3 products using three variables.

# %%
p1 = 117
p2 = 249
p3 = 199

total = p1 + p2 + p3

print(total)

# %% [markdown]
# ### 30. Write a program to take a student's name and marks in 3 subjects, then print the name, total marks, and average marks.

# %%
name = input("Enter student's name: ")

sub1 = int(input("Enter subject 1 mark : "))
sub2 = int(input("Enter subject 2 mark : "))
sub3 = int(input("Enter subject 3 mark : "))

total = sub1 + sub2 + sub3
average = total / 3

print("Name:", name)
print("Total Marks:", total)
print("Average Marks:", average)
