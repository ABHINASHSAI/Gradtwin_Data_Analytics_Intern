# %% [markdown]
# Bitwise Operators

# %% [markdown]
# 1.AND

# %%
a = 5
b = 3

print("AND :",a & b)
# Out:
# AND : 1

# %% [markdown]
# Explantion
# 5 = 0101
# 3 = 0011
# & = 0001

# %%
a = 4
b = 3

print("AND :",a & b)
# Out:
# AND : 0

# %% [markdown]
# 4 = 0100
# 3 = 0011
# & = 0000

# %% [markdown]
# 2.OR

# %%
a = 5
b = 3

print("OR :",a | b)
# Out:
# OR : 7

# %% [markdown]
# Explanation:
#
# 5 =   0101
#
# 3 =   0011
# ---------
#   = 0111
# ---------

# %% [markdown]
# 3.NOT

# %%
a = 5

print(~a)
# Out:
# -6

# %% [markdown]
# LOGICAL OPERATORS

# %% [markdown]
# 1.AND

# %%
# Out:
# You can enter
