# %% [markdown]
# **Type of Data struture**

# %% [markdown]
# 1.List

# %%
course = ["Python", "SQL", "PowerBI"]

print(course)
# Out:
# ['Python', 'SQL', 'PowerBI']

# %% [markdown]
# 1.1 list Initializing and adding a list

# %%
course = ["Python", "SQL"]
print(course)

course.append("Tableau")
print(course)

course.extend(["Excel", "Statics"])
print(course)

course.insert(2, "Powerbi")
print(course)
# Out:
# ['Python', 'SQL']
# ['Python', 'SQL', 'Tableau']
# ['Python', 'SQL', 'Tableau', 'Excel', 'Statics']
# ['Python', 'SQL', 'Powerbi', 'Tableau', 'Excel', 'Statics']

# %% [markdown]
# 1.2 List Removing and deleting

# %%
course = ["Python", "SQL"]
print(course)

course.append("Tableau")
print(course)

course.extend(["Excel", "Statics"])
print(course)

course.insert(2, "Powerbi")
print(course)

print("Removing and Deleting in list")

course.pop()
print(course)

del course[0]
print(course)

course.remove("SQL")
print(course)
# Out:
# ['Python', 'SQL']
# ['Python', 'SQL', 'Tableau']
# ['Python', 'SQL', 'Tableau', 'Excel', 'Statics']
# ['Python', 'SQL', 'Powerbi', 'Tableau', 'Excel', 'Statics']
# Removing and Deleting in list
# ['Python', 'SQL', 'Powerbi', 'Tableau', 'Excel']
# ['SQL', 'Powerbi', 'Tableau', 'Excel']
# ['Powerbi', 'Tableau', 'Excel']

# %% [markdown]
# 1.3 Sorting

# %%
numbers = [17,1,7,0,7,3,8,23]

print(numbers)

numbers.reverse()
print(numbers)

numbers.sort()
print(numbers)

numbers.sort(reverse=True)
print(numbers)
# Out:
# [17, 1, 7, 0, 7, 3, 8, 23]
# [23, 8, 3, 7, 0, 7, 1, 17]
# [0, 1, 3, 7, 7, 8, 17, 23]
# [23, 17, 8, 7, 7, 3, 1, 0]

# %% [markdown]
# 1.4 Slicing

# %%
numbers = [20,45,17,98,45,73,97,20,1]

print(numbers)
print(numbers[2:5])
print(numbers[:5])
print(numbers[5:])
# Out:
# [20, 45, 17, 98, 45, 73, 97, 20, 1]
# [17, 98, 45]
# [20, 45, 17, 98, 45]
# [73, 97, 20, 1]

# %% [markdown]
# 2.Tuple

# %%
numbers = (10, 20, 30)

print(numbers)
print(numbers[1])
# Out:
# (10, 20, 30)
# 20

# %% [markdown]
# 2.1 InInitializing and adding a Tuples

# %%
numbers = (10, 20, 30)

print(numbers)
print(numbers[1])
# Out:
# (10, 20, 30)
# 20

# %% [markdown]
# 2.2 Length and count of the tuple

# %%
numbers = (10, 20, 30, 10, 30, 10, 50, 30)
print(numbers)
print(len(numbers))
print(numbers.count(10))
# Out:
# (10, 20, 30, 10, 30, 10, 50, 30)
# 8
# 3

# %% [markdown]
# 2.3 Adding 2 tuples into 1

# %%
data_type1 = ("Int", "Float")
data_type2 = ("String","Complex")

data_type = data_type1 + data_type2
print(data_type)
# Out:
# ('Int', 'Float', 'String', 'Complex')

# %% [markdown]
# 2.4 Slicing in tuples

# %%
months = ("Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec")

print(months)
print(months[2])
print(months[2:5])
print(months[:5])
print(months[5:])
# Out:
# ('Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec')
# Mar
# ('Mar', 'Apr', 'May')
# ('Jan', 'Feb', 'Mar', 'Apr', 'May')
# ('Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec')

# %% [markdown]
# 3.Set

# %%
numbers = {10,20,10,30}
print(numbers)
# Out:
# {10, 20, 30}

# %% [markdown]
# 3.1 initialzing and length of the set

# %%
set = {1, 2, 3, 4, 5, 2, 3}
print(set)
print("Length of the set:", len(my_set))
# Out:
# {1, 2, 3, 4, 5}
# Length of the set: 5

# %% [markdown]
# 3.2 Slicing of set

# %%
set = {7,17,9,6,4,3,8,2,9,7,1}
print(set)
# Out:
# {1, 2, 3, 4, 6, 7, 8, 9, 17}

# %% [markdown]
# 4.Dictionary

# %%
employee = {
    "emp_name": "Ram",
    "emp_age": 23,
    "emp_id" : 1710,
    "emp_role" : "Data Analytics",
    "emp_salary" : 30000
}

print(employee)

employee['emp_salary'] = 35000

print("Updated :",employee)

employee ["emp_no"] = [9989900]

print(employee)

employee.pop ("emp_no")

print(employee)
# Out:
# {'emp_name': 'Ram', 'emp_age': 23, 'emp_id': 1710, 'emp_role': 'Data Analytics', 'emp_salary': 30000}
# Updated : {'emp_name': 'Ram', 'emp_age': 23, 'emp_id': 1710, 'emp_role': 'Data Analytics', 'emp_salary': 35000}
# {'emp_name': 'Ram', 'emp_age': 23, 'emp_id': 1710, 'emp_role': 'Data Analytics', 'emp_salary': 35000, 'emp_no': [9989900]}
# {'emp_name': 'Ram', 'emp_age': 23, 'emp_id': 1710, 'emp_role': 'Data Analytics', 'emp_salary': 35000}

# %% [markdown]
# Condition Statment

# %% [markdown]
# 1.if-else condition

# %%
age = int(input("Enter your Age : "))

if age >= 18:
  print("Your are eligible")
else:
  print("Your are eligible")
# Out:
# Enter your Age : 67
# Your are eligible

# %% [markdown]
# 1.1 to check positive number or not

# %%
n = int(input("Enter a number : "))

if n > 0:
  print("Positive Number")
else:
  print("Negative Number")
# Out:
# Enter a number : 6
# Positive Number

# %% [markdown]
# 1.2 to checck even number or odd number

# %%
n = int(input("Enter a number : "))

if n % 2 == 0:
  print("Even Number")
else:
  print("Odd Number")
# Out:
# Enter a number : 7
# Odd Number

# %% [markdown]
# 1.3 to check pass or fail in exam

# %%
mark = int(input("Enter your mark : "))

if mark >= 49:
  print("Your are Pass")
else:
  print("Your are Fail")
# Out:
# Enter your mark : 76
# Your are Pass

# %% [markdown]
# 1.4 To check greater no in given 3 numbers from the user

# %%
n1 = int(input("Enter 1st number : "))
n2 = int(input("Enter 2nd number : "))
n3 = int(input("Enter 3rd number : "))

if n1 > n2 and n1 > n3:
  print(n1, "is greater")
elif n2 > n1 and n2 > n3:
  print(n2, "is greater")
else:
  print(n3, "is greater")
# Out:
# Enter 1st number : 76
# Enter 2nd number : 54
# Enter 3rd number : 86
# 86 is greater

# %% [markdown]
# 1.5 To check temperature

# %%
n = int(input("Enter the temperature : "))

if n >= 25:
  print("It's Hot")
else :
  print("It's Cold")
# Out:
# Enter the temperature : 25
# It's Hot

# %% [markdown]
# 1.6 to check age catagory

# %%
age = int(input("Enter your age : "))

if age >= 18:
  print("Your are an adult")
else:
  print("Your are a minor")
# Out:
# Enter your age : 4
# Your are a minor

# %% [markdown]
# 1.7 To check the passwaord

# %%
passw = 1701;

n = int(input("Enter your password : "))

if n == passw:
  print("Your password is correct")
else:
  print("Your password is incorrect")
# Out:
# Enter your password : 1701
# Your password is correct

# %% [markdown]
# 1.9 To check the salary of the employee

# %%
salary =int(input("Enter your Salary :"))

if salary >= 100000:
  print("Your salary is high")
else:
  print("Your salary is low")

# %% [markdown]
# 1.10 To check it is number or not

# %%
n = input("Enter a number : ")

if n.isdigit():
  print("It's a number")
else:
  print("It's not a number")

# %% [markdown]
# 2. Elif Condition Statmnet

# %% [markdown]
# 2.1 Write a program to check whether a person is Child, Teenager, Adult, or Senior Citizen based on age.

# %%
age = int(input("Enter your age : "))

if age < 13:
  print("You are a Child")
elif age >= 13 and age < 20:
  print("You are a Teenager")
elif age >= 20 and age < 60:
  print("You are an Adult")
else:
  print("You are a Senior Citizen")

# %% [markdown]
# 2.2 Write a program to display the grade based on marks:
# 90–100 → A
# 80–89 → B
# 70–79 → C
# 60–69 → D
# Below 60 → F

# %%
mark = int(input("Enter your mark : "))

if mark >= 90 and mark <= 100:
  print("Your grade is A")
elif mark >= 80 and mark <= 89:
  print("Your grade is B")
elif mark >=70 and mark <=79:
  print("Your grade is C")
elif mark >=60 and mark <=69:
  print("Your grade is D")
else:
  print("Your grade is F")

# %% [markdown]
# 2.3 Write a program to check whether a number is positive, negative, or zero.

# %%
n = int(input("Enter a number : "))

if n > 0:
  print("Positive Number")
elif n < 0:
  print("Negative Number")
else:
  print("Zero")

# %% [markdown]
# 2.4 Write a program to display the day of the week based on a number from 1 to 7.

# %%
n = int(input("Enter a number : "))

if n == 1:
  print("Monday")
elif n == 2:
  print("Tuesday")
elif n == 3:
  print("Wednesday")
elif n == 4:
  print("Thursday")
elif n == 5:
  print("Friday")
elif n == 6:
  print("Saturday")
elif n == 7:
  print("Sunday")
else:
  print("Invalid Input")

# %% [markdown]
# 1.5 Write a program to calculate electricity bill amount based on the number of units consumed using different unit ranges.

# %%
units = int(input("Enter the number of units consumed: "))

if units <= 100:
    bill = units * 1.5
elif units <= 200:
    bill = 100 * 1.5 + (units - 100) * 2.5
elif units <= 300:
    bill = 100 * 1.5 + 100 * 2.5 + (units - 200) * 4
else:
    bill = 100 * 1.5 + 100 * 2.5 + (100 * 4) + (units - 300) * 5
print("Electricity bill amount : ", bill)
# Out:
# Enter the number of units consumed: 220
# Electricity bill amount :  480.0

# %% [markdown]
# 1.6 Write a program to identify whether a person is underweight, normal weight, overweight, or obese based on BMI.

# %%
w = int(input("Enter your weight in kg : "))
h = int(input("Enter your height in cm : "))

bmi = w / (h/100)**2

if bmi < 18.5:
  print("Underweight")
elif bmi >= 18.5 and bmi < 25:
  print("Normal Weight")
elif bmi >= 25 and bmi < 30:
  print("Overweight")
else:
  print("Obese")
# Out:
# Enter your weight in kg : 60
# Enter your height in cm : 168
# Normal Weight

# %% [markdown]
# 1.7 Write a program to display the largest of three numbers using if-elif-else.

# %%
n1 = int(input("Enter 1st number : "))
n2 = int(input("Enter 2nd number : "))
n3 = int(input("Enter 3rd number : "))

if n1>n2 and n1>n3:
  print(n1, "is largest")
elif n2>n1 and n2>n3:
  print(n2, "is largest")
else:
  print(n3, "is largest")

# %% [markdown]
# 1.8 Write a program to calculate discount based on the purchase amount:
# Below ₹1,000 → No discount
# ₹1,000–₹4,999 → 5%
# ₹5,000–₹9,999 → 10%
# ₹10,000 and above → 20%

# %%
n = int(input("Enter your purchase amount : "))

if n < 1000:
  print("No discount")
elif n >= 1000 and n <= 4999:
  print("Discount is 5%")
elif n >= 5000 and n <= 9999:
  print("Discount is 10%")
elif n >= 10000:
  print("Discount is 20%")

# %% [markdown]
# 1.9 Write a program to identify the type of triangle based on its three sides:
# Equilateral
# Isosceles
# Scalene

# %%
s1 = int(input("Enter first side: "))
s2 = int(input("Enter second side: "))
s3 = int(input("Enter third side: "))

if s1 == s2 and s2 == s3:
    print("Equilateral Triangle")

elif s1 == s2 or s2 == s3 or s1 == s3:
    print("Isosceles Triangle")

else:
    print("Scalene Triangle")
# Out:
# Enter first side: 3
# Enter second side: 4
# Enter third side: 5
# Scalene Triangle

# %% [markdown]
# 2.10 Write a program to create a simple ATM menu where the user enters a choice:
# 1 → Check Balance
# 2 → Deposit
# 3 → Withdraw
# 4 → Exit
# Any other choice → Invalid choice

# %%
print("Welcome to ATM")
print("1. Check Balance")
print("2. Deposit")
print("3. Withdraw")
print("4. Exit")

print("Enter your choice : ")

if n == 1:
  print("Check Balance")

elif n == 2:
  print("Deposit")
elif n == 3:
  print("Withdraw")
elif n == 4:
  print("Exit")
else:
  print("Invalid")
